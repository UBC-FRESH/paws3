# %% [markdown]
# # PAWS3 Debug Workbench
# Interactive notebook to test various PAWS3 system functions, as we work towards a stable release.
#
# **Tips**
# - Run this from the PAWS3 repo root (same folder as `pyproject.toml`).
# - In CodeServer/Jupyter with the debugger enabled, uncaught exceptions will pause execution.
